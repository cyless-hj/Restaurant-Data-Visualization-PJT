# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
# 한글 문제
# matplotlit의 기본 폰트에서 한글 지원되지 않기 때문에
# matplotlib의 폰트 변경 필요
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
df = pd.read_csv('./data/data_set/맛집 통합 데이터.csv')
df
# Out:
#       Unnamed: 0            식당명   별점    구                           주소  \
# 0              0             카레  4.6  성북구           서울특별시 성북구 성북로 62-1
# 1              1        도이칠란드 박  4.6  성북구     서울특별시 성북구 솔샘로6길 30-15 1F
# 2              2  뽀르께노 스페니쉬비스트로  4.6  성북구     서울특별시 성북구 동소문로6길 4-21 1F
# 3              3             공푸  4.5  성북구         서울특별시 성북구 삼선교로24길 29
# 4              4           성북동집  4.5  성북구           서울특별시 성북구 성북로24길 4
# ...          ...            ...  ...  ...                          ...
# 3995        3995         마굿간생고기  3.8  마포구      서울특별시 마포구 와우산로29라길 7 1F
# 3996        3996        그리너리샐러드  3.8  마포구             서울특별시 마포구 포은로 75
# 3997        3997             우아  3.8  마포구          서울특별시 마포구 포은로 78 2F
# 3998        3998          아르켓카페  3.8  마포구       서울특별시 마포구 토정로17안길 9 1F
# 3999        3999           모퉁이네  3.8  마포구   서울특별시 마포구 독막로15길 3-12 102호
#
#                 음식종류       가격대        리뷰날짜 리뷰평가  리뷰수  맛있다수  괜찮다수  별로다수
# ...

# %%
df = df.drop(['Unnamed: 0'],axis=1)
df
# Out:
#                 식당명   별점    구                           주소            음식종류  \
# 0                카레  4.6  성북구           서울특별시 성북구 성북로 62-1               0
# 1           도이칠란드 박  4.6  성북구     서울특별시 성북구 솔샘로6길 30-15 1F         세계음식 기타
# 2     뽀르께노 스페니쉬비스트로  4.6  성북구     서울특별시 성북구 동소문로6길 4-21 1F         세계음식 기타
# 3                공푸  4.5  성북구         서울특별시 성북구 삼선교로24길 29   정통 중식 / 일반 중식
# 4              성북동집  4.5  성북구           서울특별시 성북구 성북로24길 4       국수 / 면 요리
# ...             ...  ...  ...                          ...             ...
# 3995         마굿간생고기  3.8  마포구      서울특별시 마포구 와우산로29라길 7 1F           고기 요리
# 3996        그리너리샐러드  3.8  마포구             서울특별시 마포구 포은로 75           기타 양식
# 3997             우아  3.8  마포구          서울특별시 마포구 포은로 78 2F     치킨 / 호프 / 펍
# 3998          아르켓카페  3.8  마포구       서울특별시 마포구 토정로17안길 9 1F        카페 / 디저트
# 3999           모퉁이네  3.8  마포구   서울특별시 마포구 독막로15길 3-12 102호           기타 한식
#
#            가격대        리뷰날짜 리뷰평가  리뷰수  맛있다수  괜찮다수  별로다수
# ...

# %%
a = df.별점 >= 4
b = df.리뷰수 >= 20
df = df[a & b]

# %%
df
# Out:
#           식당명   별점    구                               주소              음식종류  \
# 0          카레  4.6  성북구               서울특별시 성북구 성북로 62-1                 0
# 1     도이칠란드 박  4.6  성북구         서울특별시 성북구 솔샘로6길 30-15 1F           세계음식 기타
# 3          공푸  4.5  성북구             서울특별시 성북구 삼선교로24길 29     정통 중식 / 일반 중식
# 4        성북동집  4.5  성북구               서울특별시 성북구 성북로24길 4         국수 / 면 요리
# 7        우정초밥  4.4  성북구            서울특별시 성북구 종암로3길 31 1F            회 / 스시
# ...       ...  ...  ...                              ...               ...
# 3886   헤비로테이트  4.0  마포구               서울특별시 마포구 새창로2길 17          카페 / 디저트
# 3888    카멜 커피  4.0  마포구            서울특별시 마포구 양화로23길 22-7          카페 / 디저트
# 3889    포프트커피  4.0  마포구                 서울특별시 마포구 숭문길 24          카페 / 디저트
# 3895     영원식당  4.0  마포구   서울특별시 마포구 양화로7길 6-5 와와빌딩 2동 2F         국수 / 면 요리
# 3906    진진만두국  4.0  마포구         서울 마포구 토정로3안길 18 세원빌딩 1F  한정식 / 백반 / 정통 한식
#
#            가격대        리뷰날짜 리뷰평가  리뷰수  맛있다수  괜찮다수  별로다수
# ...

# %%
df.음식종류.unique()
# Out:
# array(['0', ' 세계음식 기타', ' 정통 중식 / 일반 중식', ' 국수 / 면 요리', ' 회 / 스시',
#        ' 이탈리안', ' 기타 한식', ' 고기 요리', ' 한정식 / 백반 / 정통 한식', ' 인도 음식',
#        ' 탕 / 찌개 / 전골', ' 카페 / 디저트', ' 브런치 / 버거 / 샌드위치', ' 기타 중식',
#        ' 기타 양식', ' 스테이크 / 바베큐', ' 까스 요리', ' 딤섬 / 만두', ' 해산물 요리',
#        ' 다국적 아시아 음식', ' 남미 음식', ' 베이커리', ' 칵테일 / 와인', ' 라멘 / 소바 / 우동',
#        ' 치킨 / 호프 / 펍', ' 전통 주점 / 포차', ' 태국 음식', ' 퓨전 양식', ' 철판 요리',
#        ' 베트남 음식', ' 이자카야 / 오뎅 / 꼬치', ' 정통 일식 / 일반 일식', ' 프랑스 음식',
#        ' 다국적 퓨전', ' 돈부리 / 일본 카레 / 벤토', ' 패밀리 레스토랑', ' 퓨전 한식', ' 퓨전 중식',
#        ' 닭 / 오리 요리', ' 일반 주점', ' 퓨전 일식', ' 기타 일식', ' 뷔페', '정통 중식 / 일반 중식',
#        '닭 / 오리 요리', '정통 일식 / 일반 일식', '세계음식 기타', '라멘 / 소바 / 우동',
#        '다국적 아시아 음식', '기타 중식', '기타 양식', '카페 / 디저트', '이탈리안',
#        '브런치 / 버거 / 샌드위치', '고기 요리', '국수 / 면 요리', '한정식 / 백반 / 정통 한식',
#        '전통 주점 / 포차', '남미 음식', '탕 / 찌개 / 전골', '딤섬 / 만두', '해산물 요리', '철판 요리',
#        '스테이크 / 바베큐', '돈부리 / 일본 카레 / 벤토', '퓨전 중식', '이자카야 / 오뎅 / 꼬치',
# ...

# %%
df['음식종류']=df['음식종류'].str.replace(' ','')
# Out:
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\333362103.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace(' ','')

# %%
df
# Out:
#           식당명   별점    구                               주소         음식종류  \
# 0          카레  4.6  성북구               서울특별시 성북구 성북로 62-1            0
# 1     도이칠란드 박  4.6  성북구         서울특별시 성북구 솔샘로6길 30-15 1F       세계음식기타
# 3          공푸  4.5  성북구             서울특별시 성북구 삼선교로24길 29    정통중식/일반중식
# 4        성북동집  4.5  성북구               서울특별시 성북구 성북로24길 4       국수/면요리
# 7        우정초밥  4.4  성북구            서울특별시 성북구 종암로3길 31 1F         회/스시
# ...       ...  ...  ...                              ...          ...
# 3886   헤비로테이트  4.0  마포구               서울특별시 마포구 새창로2길 17       카페/디저트
# 3888    카멜 커피  4.0  마포구            서울특별시 마포구 양화로23길 22-7       카페/디저트
# 3889    포프트커피  4.0  마포구                 서울특별시 마포구 숭문길 24       카페/디저트
# 3895     영원식당  4.0  마포구   서울특별시 마포구 양화로7길 6-5 와와빌딩 2동 2F       국수/면요리
# 3906    진진만두국  4.0  마포구         서울 마포구 토정로3안길 18 세원빌딩 1F  한정식/백반/정통한식
#
#            가격대        리뷰날짜 리뷰평가  리뷰수  맛있다수  괜찮다수  별로다수
# 0        만원 미만  2022-08-03  맛있다   78  68.0   7.0   3.0
# ...

# %%
df['음식종류']=df['음식종류'].str.replace('국수/면요리','한식')
df['음식종류']=df['음식종류'].str.replace('기타한식','한식')
df['음식종류']=df['음식종류'].str.replace('고기요리','한식')
df['음식종류']=df['음식종류'].str.replace('한정식/백반/정통 한식','한식')
df['음식종류']=df['음식종류'].str.replace('탕/찌개/전골','한식')
df['음식종류']=df['음식종류'].str.replace('닭/오리요리','한식')
df['음식종류']=df['음식종류'].str.replace('퓨전한식','한식')
# Out:
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\1334282256.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace('국수/면요리','한식')
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\1334282256.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace('기타한식','한식')
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\1334282256.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df['음식종류']=df['음식종류'].str.replace('정통중식','중식')
df['음식종류']=df['음식종류'].str.replace('일반중식','중식')
df['음식종류']=df['음식종류'].str.replace('기타중식','중식')
df['음식종류']=df['음식종류'].str.replace('딤섬/만두','중식')
df['음식종류']=df['음식종류'].str.replace('퓨전중식','중식')
# Out:
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\3885337091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace('정통중식','중식')
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\3885337091.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace('일반중식','중식')
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\3885337091.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
len(df.음식종류.unique())
# Out:
# 37

# %%
df['음식종류']=df['음식종류'].str.replace('회/스시','일식')
df['음식종류']=df['음식종류'].str.replace('까스요리','일식')
df['음식종류']=df['음식종류'].str.replace('라멘/소바/우동','일식')
df['음식종류']=df['음식종류'].str.replace('철판요리','일식')
df['음식종류']=df['음식종류'].str.replace('정통일식/일반 일식','일식')
df['음식종류']=df['음식종류'].str.replace('돈부리/일본카레/벤토','일식')
df['음식종류']=df['음식종류'].str.replace('퓨전일식','일식')
df['음식종류']=df['음식종류'].str.replace('기타일식','일식')
# Out:
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\311889555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace('회/스시','일식')
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\311889555.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace('까스요리','일식')
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\311889555.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
len(df.음식종류.unique())
# Out:
# 31

# %%
df['음식종류']=df['음식종류'].str.replace('이탈리안','양식')
df['음식종류']=df['음식종류'].str.replace('브런치/버거/샌드위치','양식')
df['음식종류']=df['음식종류'].str.replace('기타양식','양식')
df['음식종류']=df['음식종류'].str.replace('스테이크/바베큐','양식')
df['음식종류']=df['음식종류'].str.replace('퓨전양식','양식')
df['음식종류']=df['음식종류'].str.replace('패밀리레스토랑','양식')
# Out:
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\623893828.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace('이탈리안','양식')
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\623893828.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace('브런치/버거/샌드위치','양식')
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\623893828.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
len(df.음식종류.unique())
# Out:
# 26

# %%
df['음식종류']=df['음식종류'].str.replace('세계음식기타','다국적음식')
df['음식종류']=df['음식종류'].str.replace('인도음식','다국적음식')
df['음식종류']=df['음식종류'].str.replace('다국적아시아 음식','다국적음식')
df['음식종류']=df['음식종류'].str.replace('남미음식','다국적음식')
df['음식종류']=df['음식종류'].str.replace('태국음식','다국적음식')
df['음식종류']=df['음식종류'].str.replace('베트남음식','다국적음식')
df['음식종류']=df['음식종류'].str.replace('프랑스음식','다국적음식')
df['음식종류']=df['음식종류'].str.replace('다국적퓨전','다국적음식')
# Out:
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\3328600587.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace('세계음식기타','다국적음식')
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\3328600587.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace('인도음식','다국적음식')
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\3328600587.py:3: SettingWithCopyWarning:
# ...

# %%
len(df.음식종류.unique())
# Out:
# 20

# %%
df['음식종류']=df['음식종류'].str.replace('카페/디저트','카페/디저트')
df['음식종류']=df['음식종류'].str.replace('베이커리','카페/디저트')
# Out:
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\3587877188.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace('카페/디저트','카페/디저트')
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\3587877188.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace('베이커리','카페/디저트')

# %%
len(df.음식종류.unique())
# Out:
# 19

# %%
df['음식종류']=df['음식종류'].str.replace('해산물요리','기타')
df['음식종류']=df['음식종류'].str.replace('시푸드요리','기타')
# Out:
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\2720431450.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace('해산물요리','기타')
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\2720431450.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace('시푸드요리','기타')

# %%
df['음식종류']=df['음식종류'].str.replace('칵테일/와인','주점')
df['음식종류']=df['음식종류'].str.replace('치킨/호프/펍','주점')
df['음식종류']=df['음식종류'].str.replace('전통주점/포차','주점')
df['음식종류']=df['음식종류'].str.replace('이자카야/오뎅/꼬치','주점')
df['음식종류']=df['음식종류'].str.replace('일반주점','주점')
df['음식종류']=df['음식종류'].str.replace('포차','주점')
df['음식종류']=df['음식종류'].str.replace('뷔페','뷔페')
# Out:
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\3015520605.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace('칵테일/와인','주점')
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\3015520605.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace('치킨/호프/펍','주점')
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\3015520605.py:3: SettingWithCopyWarning:
# ...

# %%
len(df.음식종류.unique())
# Out:
# 14

# %%
df.음식종류.unique()
# Out:
# array(['0', '다국적음식', '중식/중식', '한식', '일식', '양식', '한정식/백반/정통한식', '카페/디저트',
#        '중식', '기타', '다국적아시아음식', '주점', '정통일식/일반일식', '뷔페'], dtype=object)

# %%
df['음식종류']=df['음식종류'].str.replace('한정식/백반/정통한식','한식')
df['음식종류']=df['음식종류'].str.replace('정통일식/일반일식','일식')
df['음식종류']=df['음식종류'].str.replace('중식/중식','중식')
# Out:
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\677432090.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace('한정식/백반/정통한식','한식')
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\677432090.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace('정통일식/일반일식','일식')
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\677432090.py:3: SettingWithCopyWarning:
# ...

# %%
len(df.음식종류.unique())
# Out:
# 11

# %%
df.음식종류.unique()
# Out:
# array(['0', '다국적음식', '중식', '한식', '일식', '양식', '카페/디저트', '기타', '다국적아시아음식',
#        '주점', '뷔페'], dtype=object)

# %%
df.head()
# Out:
#        식당명   별점    구                         주소   음식종류       가격대        리뷰날짜  \
# 0       카레  4.6  성북구         서울특별시 성북구 성북로 62-1      0     만원 미만  2022-08-03
# 1  도이칠란드 박  4.6  성북구   서울특별시 성북구 솔샘로6길 30-15 1F  다국적음식    만원-2만원  2022-07-04
# 3       공푸  4.5  성북구       서울특별시 성북구 삼선교로24길 29     중식     만원 미만  2022-07-07
# 4     성북동집  4.5  성북구         서울특별시 성북구 성북로24길 4     한식    만원-2만원  2022-07-28
# 7     우정초밥  4.4  성북구      서울특별시 성북구 종암로3길 31 1F     일식   2만원-3만원  2022-06-18
#
#   리뷰평가  리뷰수  맛있다수  괜찮다수  별로다수
# 0  맛있다   78  68.0   7.0   3.0
# 1  맛있다   21  19.0   0.0   2.0
# 3   별로   91  76.0  11.0   4.0
# 4  맛있다   41  35.0   6.0   0.0
# 7  맛있다   31  28.0   3.0   0.0

# %%
df['음식종류']=df['음식종류'].str.replace('0','x')
# Out:
# C:\Users\HYUNJIN\AppData\Local\Temp\ipykernel_13956\2215796079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['음식종류']=df['음식종류'].str.replace('0','x')

# %%
df
# Out:
#           식당명   별점    구                               주소    음식종류       가격대  \
# 0          카레  4.6  성북구               서울특별시 성북구 성북로 62-1       x     만원 미만
# 1     도이칠란드 박  4.6  성북구         서울특별시 성북구 솔샘로6길 30-15 1F   다국적음식    만원-2만원
# 3          공푸  4.5  성북구             서울특별시 성북구 삼선교로24길 29      중식     만원 미만
# 4        성북동집  4.5  성북구               서울특별시 성북구 성북로24길 4      한식    만원-2만원
# 7        우정초밥  4.4  성북구            서울특별시 성북구 종암로3길 31 1F      일식   2만원-3만원
# ...       ...  ...  ...                              ...     ...       ...
# 3886   헤비로테이트  4.0  마포구               서울특별시 마포구 새창로2길 17  카페/디저트     만원 미만
# 3888    카멜 커피  4.0  마포구            서울특별시 마포구 양화로23길 22-7  카페/디저트     만원 미만
# 3889    포프트커피  4.0  마포구                 서울특별시 마포구 숭문길 24  카페/디저트     만원 미만
# 3895     영원식당  4.0  마포구   서울특별시 마포구 양화로7길 6-5 와와빌딩 2동 2F      한식     만원 미만
# 3906    진진만두국  4.0  마포구         서울 마포구 토정로3안길 18 세원빌딩 1F      한식    만원-2만원
#
#             리뷰날짜 리뷰평가  리뷰수  맛있다수  괜찮다수  별로다수
# ...

# %%
df.where(df.음식종류 == 'x').dropna().index
# Out:
# Int64Index([   0,   14,  602,  607,  611,  614,  669,  723,  854,  856,  866,
#              972,  991, 1621, 1921, 2008, 2033, 2099, 2107, 2112, 2171, 2193,
#             2200, 2218, 2235, 2292, 2369, 2404, 2429, 2432, 2448, 2468, 2643],
#            dtype='int64')

# %%
df.value_counts('구')
# Out:
# 구
# 마포구     347
# 동대문구    301
# 성북구     254
# 서대문구    142
# 중랑구      86
# dtype: int64

# %%
df_1 = df.drop([   0,   14,  602,  607,  611,  614,  669,  723,  854,  856,  866,\
             972,  991, 1621, 1921, 2008, 2033, 2099, 2107, 2112, 2171, 2193,\
            2200, 2218, 2235, 2292, 2369, 2404, 2429, 2432, 2448, 2468, 2643], axis = 0)

# %%
df_1
# Out:
#           식당명   별점    구                               주소    음식종류       가격대  \
# 1     도이칠란드 박  4.6  성북구         서울특별시 성북구 솔샘로6길 30-15 1F   다국적음식    만원-2만원
# 3          공푸  4.5  성북구             서울특별시 성북구 삼선교로24길 29      중식     만원 미만
# 4        성북동집  4.5  성북구               서울특별시 성북구 성북로24길 4      한식    만원-2만원
# 7        우정초밥  4.4  성북구            서울특별시 성북구 종암로3길 31 1F      일식   2만원-3만원
# 8          모짜  4.4  성북구                서울특별시 성북구 성북로 102      양식    만원-2만원
# ...       ...  ...  ...                              ...     ...       ...
# 3886   헤비로테이트  4.0  마포구               서울특별시 마포구 새창로2길 17  카페/디저트     만원 미만
# 3888    카멜 커피  4.0  마포구            서울특별시 마포구 양화로23길 22-7  카페/디저트     만원 미만
# 3889    포프트커피  4.0  마포구                 서울특별시 마포구 숭문길 24  카페/디저트     만원 미만
# 3895     영원식당  4.0  마포구   서울특별시 마포구 양화로7길 6-5 와와빌딩 2동 2F      한식     만원 미만
# 3906    진진만두국  4.0  마포구         서울 마포구 토정로3안길 18 세원빌딩 1F      한식    만원-2만원
#
#             리뷰날짜 리뷰평가  리뷰수  맛있다수  괜찮다수  별로다수
# ...

# %%
df_1.reset_index(drop=True, inplace = True)

# %%
df_1
# Out:
#           식당명   별점    구                               주소    음식종류       가격대  \
# 0     도이칠란드 박  4.6  성북구         서울특별시 성북구 솔샘로6길 30-15 1F   다국적음식    만원-2만원
# 1          공푸  4.5  성북구             서울특별시 성북구 삼선교로24길 29      중식     만원 미만
# 2        성북동집  4.5  성북구               서울특별시 성북구 성북로24길 4      한식    만원-2만원
# 3        우정초밥  4.4  성북구            서울특별시 성북구 종암로3길 31 1F      일식   2만원-3만원
# 4          모짜  4.4  성북구                서울특별시 성북구 성북로 102      양식    만원-2만원
# ...       ...  ...  ...                              ...     ...       ...
# 1092   헤비로테이트  4.0  마포구               서울특별시 마포구 새창로2길 17  카페/디저트     만원 미만
# 1093    카멜 커피  4.0  마포구            서울특별시 마포구 양화로23길 22-7  카페/디저트     만원 미만
# 1094    포프트커피  4.0  마포구                 서울특별시 마포구 숭문길 24  카페/디저트     만원 미만
# 1095     영원식당  4.0  마포구   서울특별시 마포구 양화로7길 6-5 와와빌딩 2동 2F      한식     만원 미만
# 1096    진진만두국  4.0  마포구         서울 마포구 토정로3안길 18 세원빌딩 1F      한식    만원-2만원
#
#             리뷰날짜 리뷰평가  리뷰수  맛있다수  괜찮다수  별로다수
# ...

# %%
df_1.to_csv('./data/data_set/조건에 맞는 맛집 추출.csv')

# %%
df_1.value_counts('구')
# Out:
# 구
# 마포구     341
# 동대문구    296
# 성북구     245
# 서대문구    134
# 중랑구      81
# dtype: int64

# %%
ordered_index = df_1.value_counts('구').index
plt.figure(figsize=(10,8))
ax = sns.countplot(y = '구', data = df_1, order = ordered_index)
plt.title('도시별 맛집 수')
plt.xlabel('맛집수')
plt.ylabel('도시')
    
for p in ax.patches:
    ax.annotate('{:.0f}개'.format(p.get_width()), (p.get_width(), p.get_y() + 0.5))
