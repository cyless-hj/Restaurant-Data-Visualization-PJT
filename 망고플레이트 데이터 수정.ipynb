# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/data_set/맛집(송파구,강남구,강서구,양천구,영등포구)(수정).csv')

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0      식당명   별점     구  \
# 0               0           0      오향가  4.7   송파구
# 1               1           1  돌마리유황오리  4.7   송파구
# 2               2           2      레브어  4.7   송파구
# 3               3           3      세이류  4.6   송파구
# 4               4           4      차만다  4.6   송파구
# ..            ...         ...      ...  ...   ...
# 995           995         995   마굿간생고기  3.8  영등포구
# 996           996         996  그리너리샐러드  3.8  영등포구
# 997           997         997       우아  3.8  영등포구
# 998           998         998    아르켓카페  3.8  영등포구
# 999           999         999     모퉁이네  3.8  영등포구
#
#                                   주소           전화번호                 음식종류  \
# 0                  서울특별시 송파구 송이로 106    02-401-6999  음식 종류 정통 중식 / 일반 중식
# 1                   서울특별시 송파구 가락로 66    02-423-6231      음식 종류 닭 / 오리 요리
# 2            서울특별시 송파구 백제고분로45길 6 1F  070-7547-9784         음식 종류 프랑스 음식
# ...

# %%
df.drop('Unnamed: 0.1', axis = 1, inplace = True)
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df
# Out:
#          식당명   별점     구                               주소           전화번호  \
# 0        오향가  4.7   송파구                서울특별시 송파구 송이로 106    02-401-6999
# 1    돌마리유황오리  4.7   송파구                 서울특별시 송파구 가락로 66    02-423-6231
# 2        레브어  4.7   송파구          서울특별시 송파구 백제고분로45길 6 1F  070-7547-9784
# 3        세이류  4.6   송파구     서울특별시 송파구 올림픽로35가길 9 B1 B35호    02-418-2288
# 4        차만다  4.6   송파구          서울특별시 송파구 오금로18길 6 106호   02-6465-0812
# ..       ...  ...   ...                              ...            ...
# 995   마굿간생고기  3.8  영등포구           서울특별시 영등포구 영중로4길 14 1F   02-2677-5849
# 996  그리너리샐러드  3.8  영등포구           서울특별시 영등포구 은행로 29 정우빌딩    02-782-9242
# 997       우아  3.8  영등포구              서울특별시 영등포구 여의나루로 42  010-2456-5782
# 998    아르켓카페  3.8  영등포구     서울특별시 영등포구 여의대로 108 더현대서울 B2   02-3277-8416
# 999     모퉁이네  3.8  영등포구  서울특별시 영등포구 국제금융로6길 33 여의도백화점 B1    02-784-9603
#
#                     음식종류          가격대                  주차  \
# ...

# %%
i = 0
for i in range(0,1000):
    if df.loc[i, '음식종류'] != 0:
        df.loc[i, '음식종류'] = df.loc[i, '음식종류'].split('음식 종류 ')[1]
    else:
        df.loc[i, '음식종류'] = 0

# %%
wrong = df['가격대'].str.contains("가격대")
wrong_df = df[~wrong]
wrong_df.index
# Out:
# Int64Index([1, 178, 427, 535, 690, 738, 745, 760, 767, 775, 784], dtype='int64')

# %%
for i in [1, 178, 427, 535, 690, 738, 745, 760, 767, 775, 784]:
    print(df.loc[i, '가격대'])
# Out:
# 주차 무료주차 가능
# 0
# 주차 주차공간없음
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
for i in [178, 767]:
    df.loc[i, '가격대'] = 0

# %%
li = [1, 427]
for i in li:
    a = df.loc[i, '가격대']
    b = df.loc[i, '주차']
    
    df.loc[i, '주차'] = a
    df.loc[i, '가격대'] = 0

# %%
li = [1, 427]
for i in li:
    print(df.loc[i, '주차'])
# Out:
# 주차 무료주차 가능
# 주차 주차공간없음

# %%
wrong = df['주차'].str.contains("영업시간")
wrong_df = df[wrong]
wrong_df.index
# Out:
# Int64Index([ 13,  31,  32,  61,  86,  91,  93,  95, 114, 149, 151, 325, 347,
#             426, 517, 542, 552, 704, 717, 747, 839, 859, 878, 905, 953],
#            dtype='int64')

# %%
li = [ 13,  31,  32,  61,  86,  91,  93,  95, 114, 149, 151, 325, 347,\
            426, 517, 542, 552, 704, 717, 747, 839, 859, 878, 905, 953]
for i in li:
    a = df.loc[i, '주차']
    
    df.loc[i, '영업시간'] = a
    df.loc[i, '주차'] = 0

# %%
wrong = df['주차'].str.contains("메뉴")
wrong1 = df['주차'].str.contains("웹 사이트 식당 홈페이지로 가기")
wrong_df = df[wrong | wrong1]
wrong_df.index
# Out:
# Int64Index([ 29,  56,  64,  94, 116, 117, 144, 146, 162, 164, 194, 261, 329,
#             337, 340, 344, 406, 410, 419, 432, 437, 443, 444, 464, 470, 476,
#             480, 488, 491, 498, 506, 516, 518, 520, 529, 532, 539, 540, 565,
#             574, 587, 594, 596, 601, 609, 614, 635, 636, 663, 668, 677, 680,
#             682, 709, 739, 740, 741, 743, 761, 762, 765, 771, 774, 777, 782,
#             783, 805, 812, 835, 841, 890, 929, 950, 957, 981, 997],
#            dtype='int64')

# %%
li = [ 29,  56,  64,  94, 116, 117, 144, 146, 162, 164, 194, 261, 329,\
            337, 340, 344, 406, 410, 419, 432, 437, 443, 444, 464, 470, 476,\
            480, 488, 491, 498, 506, 516, 518, 520, 529, 532, 539, 540, 565,\
            574, 587, 594, 596, 601, 609, 614, 635, 636, 663, 668, 677, 680,\
            682, 709, 739, 740, 741, 743, 761, 762, 765, 771, 774, 777, 782,\
            783, 805, 812, 835, 841, 890, 929, 950, 957, 981, 997]
for i in li:
    df.loc[i, '주차'] = 0

# %%
df.to_csv('./data/data_set/맛집(송파구,강남구,강서구,양천구,영등포구)(수정)2.csv')

# %%
df.head()
# Out:
#        식당명   별점    구                            주소           전화번호  \
# 0      오향가  4.7  송파구             서울특별시 송파구 송이로 106    02-401-6999
# 1  돌마리유황오리  4.7  송파구              서울특별시 송파구 가락로 66    02-423-6231
# 2      레브어  4.7  송파구       서울특별시 송파구 백제고분로45길 6 1F  070-7547-9784
# 3      세이류  4.6  송파구  서울특별시 송파구 올림픽로35가길 9 B1 B35호    02-418-2288
# 4      차만다  4.6  송파구       서울특별시 송파구 오금로18길 6 106호   02-6465-0812
#
#             음식종류          가격대          주차               영업시간  \
# 0  정통 중식 / 일반 중식   가격대 만원-2만원  주차 무료주차 가능  ['11:30 - 22:00']
# 1      닭 / 오리 요리            0  주차 무료주차 가능  ['15:00 - 17:00']
# 2         프랑스 음식  가격대 2만원-3만원   주차 주차공간없음  ['17:00 - 24:00']
# 3  정통 일식 / 일반 일식   가격대 4만원 이상  주차 무료주차 가능  ['12:00 - 21:30']
# 4        세계음식 기타   가격대 만원-2만원   주차 주차공간없음  ['11:30 - 21:30']
#
#                                                   메뉴        리뷰날짜 리뷰평가  리뷰수  \
# 0  ['오향족발 (대)', '40,000원', '냉채족발 (대)', '40,000원',...  2022-08-10  맛있다  116
# ...

# %%
df.tail()
# Out:
#          식당명   별점     구                               주소           전화번호  \
# 995   마굿간생고기  3.8  영등포구           서울특별시 영등포구 영중로4길 14 1F   02-2677-5849
# 996  그리너리샐러드  3.8  영등포구           서울특별시 영등포구 은행로 29 정우빌딩    02-782-9242
# 997       우아  3.8  영등포구              서울특별시 영등포구 여의나루로 42  010-2456-5782
# 998    아르켓카페  3.8  영등포구     서울특별시 영등포구 여의대로 108 더현대서울 B2   02-3277-8416
# 999     모퉁이네  3.8  영등포구  서울특별시 영등포구 국제금융로6길 33 여의도백화점 B1    02-784-9603
#
#             음식종류          가격대          주차  \
# 995        고기 요리   가격대 만원-2만원   주차 주차공간없음
# 996        기타 양식    가격대 만원 미만   주차 주차공간없음
# 997  치킨 / 호프 / 펍  가격대 2만원-3만원           0
# 998     카페 / 디저트    가격대 만원 미만  주차 유료주차 가능
# 999        기타 한식    가격대 만원 미만   주차 주차공간없음
#
#                                              영업시간 메뉴        리뷰날짜 리뷰평가  리뷰수  \
# 995                             ['12:00 - 02:00']  0  2022-04-06  맛있다   17
# 996                             ['09:00 - 21:00']  0  2022-02-25  괜찮다   13
# ...

# %%
r_df = df[['식당명', '별점', '구', '주소', '음식종류', '가격대' ,'리뷰날짜', '리뷰평가', '리뷰수', '맛있다수', '괜찮다수', '별로다수']]

# %%
r_df
# Out:
#          식당명   별점     구                               주소           음식종류  \
# 0        오향가  4.7   송파구                서울특별시 송파구 송이로 106  정통 중식 / 일반 중식
# 1    돌마리유황오리  4.7   송파구                 서울특별시 송파구 가락로 66      닭 / 오리 요리
# 2        레브어  4.7   송파구          서울특별시 송파구 백제고분로45길 6 1F         프랑스 음식
# 3        세이류  4.6   송파구     서울특별시 송파구 올림픽로35가길 9 B1 B35호  정통 일식 / 일반 일식
# 4        차만다  4.6   송파구          서울특별시 송파구 오금로18길 6 106호        세계음식 기타
# ..       ...  ...   ...                              ...            ...
# 995   마굿간생고기  3.8  영등포구           서울특별시 영등포구 영중로4길 14 1F          고기 요리
# 996  그리너리샐러드  3.8  영등포구           서울특별시 영등포구 은행로 29 정우빌딩          기타 양식
# 997       우아  3.8  영등포구              서울특별시 영등포구 여의나루로 42    치킨 / 호프 / 펍
# 998    아르켓카페  3.8  영등포구     서울특별시 영등포구 여의대로 108 더현대서울 B2       카페 / 디저트
# 999     모퉁이네  3.8  영등포구  서울특별시 영등포구 국제금융로6길 33 여의도백화점 B1          기타 한식
#
#              가격대        리뷰날짜 리뷰평가  리뷰수   맛있다수  괜찮다수  별로다수
# ...

# %%
r_df.to_csv('./data/data_set/맛집 데이터 수정본(정현진).csv')
