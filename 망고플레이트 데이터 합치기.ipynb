# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('./data/new/김경민.csv')
df2 = pd.read_csv('./data/new/김승규.csv')
df3 = pd.read_csv('./data/new/이선희.csv')
df4 = pd.read_csv('./data/new/정현진.csv')
df5 = pd.read_csv('./data/new/정서연.csv')

# %%
df = pd.concat([df1, df2, df3, df4, df5])

# %%
df
# Out:
#      Unnamed: 0            식당명   별점    구                                   주소  \
# 0             0             카레  4.6  성북구                주소 서울특별시 성북구 성북로 62-1
# 1             1        도이칠란드 박  4.6  성북구          주소 서울특별시 성북구 솔샘로6길 30-15 1F
# 2             2  뽀르께노 스페니쉬비스트로  4.6  성북구          주소 서울특별시 성북구 동소문로6길 4-21 1F
# 3             3             공푸  4.5  성북구              주소 서울특별시 성북구 삼선교로24길 29
# 4             4           성북동집  4.5  성북구                주소 서울특별시 성북구 성북로24길 4
# ..          ...            ...  ...  ...                                  ...
# 995         995         무궁화대구탕  NaN  구로구              주소 서울특별시 구로구 구로동로22길 12
# 996         996        대만야시장포차  NaN  구로구           주소 서울특별시 구로구 디지털로27길 52 2F
# 997         997      더제이케이키친박스  NaN  구로구  주소 서울특별시 구로구 디지털로 288 대륭포스트타워 1차 1F
# 998         998          포36거리  NaN  구로구          주소 서울특별시 구로구 디지털로 288 대륭포스트
# 999         999          하우돈곱창  NaN  구로구            주소 서울특별시 구로구 공원로6나길 35-21
#
# ...

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)
df
# Out:
#                식당명   별점    구                                   주소  \
# 0               카레  4.6  성북구                주소 서울특별시 성북구 성북로 62-1
# 1          도이칠란드 박  4.6  성북구          주소 서울특별시 성북구 솔샘로6길 30-15 1F
# 2    뽀르께노 스페니쉬비스트로  4.6  성북구          주소 서울특별시 성북구 동소문로6길 4-21 1F
# 3               공푸  4.5  성북구              주소 서울특별시 성북구 삼선교로24길 29
# 4             성북동집  4.5  성북구                주소 서울특별시 성북구 성북로24길 4
# ..             ...  ...  ...                                  ...
# 995         무궁화대구탕  NaN  구로구              주소 서울특별시 구로구 구로동로22길 12
# 996        대만야시장포차  NaN  구로구           주소 서울특별시 구로구 디지털로27길 52 2F
# 997      더제이케이키친박스  NaN  구로구  주소 서울특별시 구로구 디지털로 288 대륭포스트타워 1차 1F
# 998          포36거리  NaN  구로구          주소 서울특별시 구로구 디지털로 288 대륭포스트
# 999          하우돈곱창  NaN  구로구            주소 서울특별시 구로구 공원로6나길 35-21
#
#                     음식종류         가격대        리뷰날짜 리뷰평가  리뷰수  맛있다수  괜찮다수  별로다수
# 0              가격대 만원 미만   주차 주차공간없음  2022-08-03  맛있다   78  68.0   7.0   3.0
# ...

# %%
df.reset_index(drop=True, inplace = True)
df
# Out:
#                 식당명   별점    구                                   주소  \
# 0                카레  4.6  성북구                주소 서울특별시 성북구 성북로 62-1
# 1           도이칠란드 박  4.6  성북구          주소 서울특별시 성북구 솔샘로6길 30-15 1F
# 2     뽀르께노 스페니쉬비스트로  4.6  성북구          주소 서울특별시 성북구 동소문로6길 4-21 1F
# 3                공푸  4.5  성북구              주소 서울특별시 성북구 삼선교로24길 29
# 4              성북동집  4.5  성북구                주소 서울특별시 성북구 성북로24길 4
# ...             ...  ...  ...                                  ...
# 4995         무궁화대구탕  NaN  구로구              주소 서울특별시 구로구 구로동로22길 12
# 4996        대만야시장포차  NaN  구로구           주소 서울특별시 구로구 디지털로27길 52 2F
# 4997      더제이케이키친박스  NaN  구로구  주소 서울특별시 구로구 디지털로 288 대륭포스트타워 1차 1F
# 4998          포36거리  NaN  구로구          주소 서울특별시 구로구 디지털로 288 대륭포스트
# 4999          하우돈곱창  NaN  구로구            주소 서울특별시 구로구 공원로6나길 35-21
#
#                      음식종류         가격대        리뷰날짜 리뷰평가  리뷰수  맛있다수  괜찮다수  별로다수
# 0               가격대 만원 미만   주차 주차공간없음  2022-08-03  맛있다   78  68.0   7.0   3.0
# ...

# %%
df['주소']=df['주소'].str.replace('주소','')
df['구']=df['구'].str.replace('서울시','')
df['음식종류']=df['음식종류'].str.replace('음식 종류','')
df['가격대']=df['가격대'].str.replace('가격대','')

# %%
df.reset_index(drop=True, inplace = True)

# %%
df.loc[2000]
# Out:
# 식당명                    회현식당
# 별점                      4.8
# 구                        중구
# 주소       서울특별시 중구 퇴계로2길 9-8
# 음식종류         이자카야 / 오뎅 / 꼬치
# 가격대                 2만원-3만원
# 리뷰날짜             2022-08-08
# 리뷰평가                    괜찮다
# 리뷰수                      41
# 맛있다수                   36.0
# 괜찮다수                    5.0
# 별로다수                    0.0
# Name: 2000, dtype: object

# %%
wrong = df['음식종류'].str.contains("가격대")
wrong_df = df[wrong]
index = wrong_df.index.to_list()
print(index)
# Out:
# [0, 14, 103, 143, 162, 164, 285, 300, 349, 355, 376, 416, 489, 562, 576, 602, 607, 611, 614, 651, 664, 669, 672, 723, 745, 758, 786, 854, 856, 866, 954, 960, 972, 991, 999, 1037, 1042, 1065, 1100, 1114, 1138, 1151, 1164, 1180, 1279, 1385, 1566, 1621, 1627, 1640, 1650, 1693, 1706, 1747, 1921, 2008, 2033, 2042, 2074, 2099, 2107, 2112, 2157, 2171, 2193, 2200, 2218, 2235, 2269, 2292, 2325, 2333, 2334, 2369, 2404, 2421, 2429, 2432, 2435, 2437, 2448, 2468, 2511, 2560, 2580, 2643, 2660, 2808, 2832, 2833, 2855, 2858, 2873, 2998, 4074, 4089, 4110, 4120, 4136, 4142, 4182, 4291, 4375, 4482, 4496, 4500, 4521, 4522, 4526, 4532, 4556, 4576, 4641, 4744, 4755, 4762, 4921, 4963, 4985]

# %%
for i in [0, 14, 103, 143, 162, 164, 285, 300, 349, 355, 376, 416, 489, 562, 576, 602, 607, 611, 614, 651, 664, 669, 672, 723, 745, 758, 786, 854, 856, 866, 954, 960, 972, 991, 999, 1037, 1042, 1065, 1100, 1114, 1138, 1151, 1164, 1180, 1279, 1385, 1566, 1621, 1627, 1640, 1650, 1693, 1706, 1747, 1921, 2008, 2033, 2042, 2074, 2099, 2107, 2112, 2157, 2171, 2193, 2200, 2218, 2235, 2269, 2292, 2325, 2333, 2334, 2369, 2404, 2421, 2429, 2432, 2435, 2437, 2448, 2468, 2511, 2560, 2580, 2643, 2660, 2808, 2832, 2833, 2855, 2858, 2873, 2998, 4074, 4089, 4110, 4120, 4136, 4142, 4182, 4291, 4375, 4482, 4496, 4500, 4521, 4522, 4526, 4532, 4556, 4576, 4641, 4744, 4755, 4762, 4921, 4963, 4985]:
    a = df.loc[i, '음식종류']
    
    df.loc[i, '가격대'] = a
    df.loc[i, '음식종류'] = 0

# %%
df
# Out:
#                 식당명   별점    구                                 주소  \
# 0                카레  4.6  성북구                 서울특별시 성북구 성북로 62-1
# 1           도이칠란드 박  4.6  성북구           서울특별시 성북구 솔샘로6길 30-15 1F
# 2     뽀르께노 스페니쉬비스트로  4.6  성북구           서울특별시 성북구 동소문로6길 4-21 1F
# 3                공푸  4.5  성북구               서울특별시 성북구 삼선교로24길 29
# 4              성북동집  4.5  성북구                 서울특별시 성북구 성북로24길 4
# ...             ...  ...  ...                                ...
# 4995         무궁화대구탕  NaN  구로구               서울특별시 구로구 구로동로22길 12
# 4996        대만야시장포차  NaN  구로구            서울특별시 구로구 디지털로27길 52 2F
# 4997      더제이케이키친박스  NaN  구로구   서울특별시 구로구 디지털로 288 대륭포스트타워 1차 1F
# 4998          포36거리  NaN  구로구           서울특별시 구로구 디지털로 288 대륭포스트
# 4999          하우돈곱창  NaN  구로구             서울특별시 구로구 공원로6나길 35-21
#
#                 음식종류        가격대        리뷰날짜 리뷰평가  리뷰수  맛있다수  괜찮다수  별로다수
# 0                  0  가격대 만원 미만  2022-08-03  맛있다   78  68.0   7.0   3.0
# ...

# %%
df['구']=df['구'].str.replace(' ','')

# %%
df['가격대']=df['가격대'].str.replace('가격대 ','')
df
# Out:
#                 식당명   별점    구                                 주소  \
# 0                카레  4.6  성북구                 서울특별시 성북구 성북로 62-1
# 1           도이칠란드 박  4.6  성북구           서울특별시 성북구 솔샘로6길 30-15 1F
# 2     뽀르께노 스페니쉬비스트로  4.6  성북구           서울특별시 성북구 동소문로6길 4-21 1F
# 3                공푸  4.5  성북구               서울특별시 성북구 삼선교로24길 29
# 4              성북동집  4.5  성북구                 서울특별시 성북구 성북로24길 4
# ...             ...  ...  ...                                ...
# 4995         무궁화대구탕  NaN  구로구               서울특별시 구로구 구로동로22길 12
# 4996        대만야시장포차  NaN  구로구            서울특별시 구로구 디지털로27길 52 2F
# 4997      더제이케이키친박스  NaN  구로구   서울특별시 구로구 디지털로 288 대륭포스트타워 1차 1F
# 4998          포36거리  NaN  구로구           서울특별시 구로구 디지털로 288 대륭포스트
# 4999          하우돈곱창  NaN  구로구             서울특별시 구로구 공원로6나길 35-21
#
#                 음식종류      가격대        리뷰날짜 리뷰평가  리뷰수  맛있다수  괜찮다수  별로다수
# 0                  0    만원 미만  2022-08-03  맛있다   78  68.0   7.0   3.0
# ...

# %%
df.to_csv('./data/new/통합.csv')

# %%
pd.set_option('display.max_rows', 200)
df.head(200)
# Out:
#                식당명   별점    구                                주소  \
# 0               카레  4.6  성북구                서울특별시 성북구 성북로 62-1
# 1          도이칠란드 박  4.6  성북구          서울특별시 성북구 솔샘로6길 30-15 1F
# 2    뽀르께노 스페니쉬비스트로  4.6  성북구          서울특별시 성북구 동소문로6길 4-21 1F
# 3               공푸  4.5  성북구              서울특별시 성북구 삼선교로24길 29
# 4             성북동집  4.5  성북구                서울특별시 성북구 성북로24길 4
# 5              계모임  4.5  성북구         서울특별시 성북구 보문로30라길 5-10 1F
# 6               옥돌  4.5  성북구              서울특별시 성북구 동소문로17길 11
# 7             우정초밥  4.4  성북구             서울특별시 성북구 종암로3길 31 1F
# 8               모짜  4.4  성북구                 서울특별시 성북구 성북로 102
# 9          일흥콩나물국밥  4.4  성북구               서울특별시 성북구 고려대로5길 77
# 10             드시소  4.4  성북구            서울특별시 성북구 보국문로 86-3 1F
# 11       마실참숯불생고기집  4.4  성북구             서울특별시 성북구 종암로38길 41-2
# 12            고른햇살  4.3  성북구                 서울특별시 성북구 개운사길 27
# 13        성북동누룽지백숙  4.3  성북구                서울특별시 성북구 성북로31길 9
# ...

# %%
df['별점'].fillna(0, inplace = True)
df['맛있다수'].fillna(0, inplace = True)
df['괜찮다수'].fillna(0, inplace = True)
df['별로다수'].fillna(0, inplace = True)
df_new = df
df_new
# Out:
#                 식당명   별점    구                                 주소  \
# 0                카레  4.6  성북구                 서울특별시 성북구 성북로 62-1
# 1           도이칠란드 박  4.6  성북구           서울특별시 성북구 솔샘로6길 30-15 1F
# 2     뽀르께노 스페니쉬비스트로  4.6  성북구           서울특별시 성북구 동소문로6길 4-21 1F
# 3                공푸  4.5  성북구               서울특별시 성북구 삼선교로24길 29
# 4              성북동집  4.5  성북구                 서울특별시 성북구 성북로24길 4
# ...             ...  ...  ...                                ...
# 4995         무궁화대구탕  0.0  구로구               서울특별시 구로구 구로동로22길 12
# 4996        대만야시장포차  0.0  구로구            서울특별시 구로구 디지털로27길 52 2F
# 4997      더제이케이키친박스  0.0  구로구   서울특별시 구로구 디지털로 288 대륭포스트타워 1차 1F
# 4998          포36거리  0.0  구로구           서울특별시 구로구 디지털로 288 대륭포스트
# 4999          하우돈곱창  0.0  구로구             서울특별시 구로구 공원로6나길 35-21
#
#                 음식종류      가격대        리뷰날짜 리뷰평가  리뷰수  맛있다수  괜찮다수  별로다수
# 0                  0    만원 미만  2022-08-03  맛있다   78  68.0   7.0   3.0
# ...

# %%
df_new['음식종류']=df_new['음식종류'].str.replace(' ','')

# %%
df_new['음식종류']=df_new['음식종류'].str.replace('국수/면요리','한식')
df_new['음식종류']=df_new['음식종류'].str.replace('기타한식','한식')
df_new['음식종류']=df_new['음식종류'].str.replace('고기요리','한식')
df_new['음식종류']=df_new['음식종류'].str.replace('한정식/백반/정통 한식','한식')
df_new['음식종류']=df_new['음식종류'].str.replace('탕/찌개/전골','한식')
df_new['음식종류']=df_new['음식종류'].str.replace('닭/오리요리','한식')
df_new['음식종류']=df_new['음식종류'].str.replace('퓨전한식','한식')
df_new['음식종류']=df_new['음식종류'].str.replace('정통중식','중식')
df_new['음식종류']=df_new['음식종류'].str.replace('일반중식','중식')
df_new['음식종류']=df_new['음식종류'].str.replace('기타중식','중식')
df_new['음식종류']=df_new['음식종류'].str.replace('딤섬/만두','중식')
df_new['음식종류']=df_new['음식종류'].str.replace('퓨전중식','중식')
df_new['음식종류']=df_new['음식종류'].str.replace('회/스시','일식')
df_new['음식종류']=df_new['음식종류'].str.replace('까스요리','일식')
df_new['음식종류']=df_new['음식종류'].str.replace('라멘/소바/우동','일식')
df_new['음식종류']=df_new['음식종류'].str.replace('철판요리','일식')
df_new['음식종류']=df_new['음식종류'].str.replace('정통일식/일반 일식','일식')
df_new['음식종류']=df_new['음식종류'].str.replace('돈부리/일본카레/벤토','일식')
df_new['음식종류']=df_new['음식종류'].str.replace('퓨전일식','일식')
df_new['음식종류']=df_new['음식종류'].str.replace('기타일식','일식')
df_new['음식종류']=df_new['음식종류'].str.replace('이탈리안','양식')
df_new['음식종류']=df_new['음식종류'].str.replace('브런치/버거/샌드위치','양식')
df_new['음식종류']=df_new['음식종류'].str.replace('기타양식','양식')
df_new['음식종류']=df_new['음식종류'].str.replace('스테이크/바베큐','양식')
df_new['음식종류']=df_new['음식종류'].str.replace('퓨전양식','양식')
df_new['음식종류']=df_new['음식종류'].str.replace('패밀리레스토랑','양식')
df_new['음식종류']=df_new['음식종류'].str.replace('세계음식기타','다국적음식')
df_new['음식종류']=df_new['음식종류'].str.replace('인도음식','다국적음식')
df_new['음식종류']=df_new['음식종류'].str.replace('다국적아시아음식','다국적음식')
df_new['음식종류']=df_new['음식종류'].str.replace('남미음식','다국적음식')
df_new['음식종류']=df_new['음식종류'].str.replace('태국음식','다국적음식')
df_new['음식종류']=df_new['음식종류'].str.replace('베트남음식','다국적음식')
df_new['음식종류']=df_new['음식종류'].str.replace('프랑스음식','다국적음식')
df_new['음식종류']=df_new['음식종류'].str.replace('다국적퓨전','다국적음식')
df_new['음식종류']=df_new['음식종류'].str.replace('카페/디저트','카페/디저트')
df_new['음식종류']=df_new['음식종류'].str.replace('베이커리','카페/디저트')
df_new['음식종류']=df_new['음식종류'].str.replace('해산물요리','기타')
df_new['음식종류']=df_new['음식종류'].str.replace('시푸드요리','기타')
df_new['음식종류']=df_new['음식종류'].str.replace('칵테일/와인','주점')
df_new['음식종류']=df_new['음식종류'].str.replace('치킨/호프/펍','주점')
df_new['음식종류']=df_new['음식종류'].str.replace('전통주점/포차','주점')
df_new['음식종류']=df_new['음식종류'].str.replace('이자카야/오뎅/꼬치','주점')
df_new['음식종류']=df_new['음식종류'].str.replace('일반주점','주점')
df_new['음식종류']=df_new['음식종류'].str.replace('포차','주점')
df_new['음식종류']=df_new['음식종류'].str.replace('뷔페','기타')
df_new['음식종류']=df_new['음식종류'].str.replace('한정식/백반/정통한식','한식')
df_new['음식종류']=df_new['음식종류'].str.replace('정통일식/일반일식','일식')
df_new['음식종류']=df_new['음식종류'].str.replace('중식/중식','중식')

# %%
df_new['평점'] = (df_new['별점'] * df_new['맛있다수'] / df_new['리뷰수']) - (df_new['별점'] * df_new['별로다수'] / df_new['리뷰수'] * 2)

# %%
df_new['평점'].fillna(0, inplace = True)
df_new
# Out:
#                 식당명   별점    구                                 주소   음식종류  \
# 0                카레  4.6  성북구                 서울특별시 성북구 성북로 62-1    NaN
# 1           도이칠란드 박  4.6  성북구           서울특별시 성북구 솔샘로6길 30-15 1F  다국적음식
# 2     뽀르께노 스페니쉬비스트로  4.6  성북구           서울특별시 성북구 동소문로6길 4-21 1F  다국적음식
# 3                공푸  4.5  성북구               서울특별시 성북구 삼선교로24길 29     중식
# 4              성북동집  4.5  성북구                 서울특별시 성북구 성북로24길 4     한식
# ...             ...  ...  ...                                ...    ...
# 4995         무궁화대구탕  0.0  구로구               서울특별시 구로구 구로동로22길 12     기타
# 4996        대만야시장포차  0.0  구로구            서울특별시 구로구 디지털로27길 52 2F     주점
# 4997      더제이케이키친박스  0.0  구로구   서울특별시 구로구 디지털로 288 대륭포스트타워 1차 1F     양식
# 4998          포36거리  0.0  구로구           서울특별시 구로구 디지털로 288 대륭포스트  다국적음식
# 4999          하우돈곱창  0.0  구로구             서울특별시 구로구 공원로6나길 35-21     한식
#
#           가격대        리뷰날짜 리뷰평가  리뷰수  맛있다수  괜찮다수  별로다수        평점
# ...

# %%
df_new = df_new.where(df_new['음식종류'] != 0).dropna()
df_new.reset_index(drop=True, inplace = True)
df_new
# Out:
#                 식당명   별점    구                                 주소   음식종류  \
# 0           도이칠란드 박  4.6  성북구           서울특별시 성북구 솔샘로6길 30-15 1F  다국적음식
# 1     뽀르께노 스페니쉬비스트로  4.6  성북구           서울특별시 성북구 동소문로6길 4-21 1F  다국적음식
# 2                공푸  4.5  성북구               서울특별시 성북구 삼선교로24길 29     중식
# 3              성북동집  4.5  성북구                 서울특별시 성북구 성북로24길 4     한식
# 4               계모임  4.5  성북구          서울특별시 성북구 보문로30라길 5-10 1F     한식
# ...             ...  ...  ...                                ...    ...
# 4876         무궁화대구탕  0.0  구로구               서울특별시 구로구 구로동로22길 12     기타
# 4877        대만야시장포차  0.0  구로구            서울특별시 구로구 디지털로27길 52 2F     주점
# 4878      더제이케이키친박스  0.0  구로구   서울특별시 구로구 디지털로 288 대륭포스트타워 1차 1F     양식
# 4879          포36거리  0.0  구로구           서울특별시 구로구 디지털로 288 대륭포스트  다국적음식
# 4880          하우돈곱창  0.0  구로구             서울특별시 구로구 공원로6나길 35-21     한식
#
#           가격대        리뷰날짜 리뷰평가  리뷰수  맛있다수  괜찮다수  별로다수        평점
# ...

# %%
df_new.to_csv('./data/data_set/맛집 데이터 통합 최종.csv')

# %%
len(df_new.where(df_new['평점'] >= 3.5).dropna())
# Out:
# 771

# %%
len(df_new.where(df_new['평점'] >= 4).dropna())
# Out:
# 359

# %%
df1 = df_new.where(df_new['평점'] >= 3.5).dropna()
df1.to_csv('./data/data_set/맛집 데이터 3.5 이상.csv')

# %%
df1['음식종류'].value_counts()
# Out:
# 카페/디저트    202
# 한식        185
# 양식         98
# 일식         86
# 주점         82
# 다국적음식      47
# 중식         42
# 기타         29
# Name: 음식종류, dtype: int64
