# %%
import pandas as pd
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
TAX = pd.read_excel('./data/지방세징수(동별)(2012년+이후)_20220817131439.xlsx',
                 usecols = ['동별(2)','2012','2013','2014', '2015', '2016', '2017', '2018', '2019','2020'])

# %%
TAX.head()
# Out:
#    동별(2)        2012        2013        2014        2015        2016  \
# 0  동별(2)          합계          합계          합계          합계          합계
# 1  동별(2)          소계          소계          소계          소계          소계
# 2  동별(2)          소계          소계          소계          소계          소계
# 3     소계  14276324.0  13870091.0  15409056.0  17972371.0  19007079.0
# 4     소계   1807592.0   1839870.0   2307731.0   2315046.0   2601002.0
#
#          2017        2018        2019        2020
# 0          합계          합계          합계          합계
# 1          소계          소계          소계          소계
# 2          소계          소계          소계          소계
# 3  20373812.0  21860524.0  23568222.0  27109152.0
# 4   2739800.0   2990921.0   3127145.0   3401490.0

# %%
# TAX = TAX.drop(TAX.index[0])

# %%
TAX.rename(columns = {'동별(2)':'구'}, inplace = True)

# %%
TAX.loc[3, '구'] = '소계(백만원 단위)'

# %%
TAX.loc[4, '구'] = '서울시 본청'

# %%
TAX.index = range(1,28)

# %%
TAX
# Out:
#              구        2012        2013        2014        2015        2016  \
# 1   소계(백만원 단위)  14276324.0  13870091.0  15409056.0  17972371.0  19007079.0
# 2       서울시 본청   1807592.0   1839870.0   2307731.0   2315046.0   2601002.0
# 3          종로구    596525.0    641709.0    662922.0    761582.0    746839.0
# 4           중구   1288216.0   1170333.0   1039202.0   1270708.0   1295444.0
# 5          용산구    459154.0    444836.0    521257.0    568306.0    638263.0
# 6          성동구    285666.0    296122.0    354070.0    398949.0    435899.0
# 7          광진구    278001.0    251637.0    277933.0    348533.0    359320.0
# 8         동대문구    288497.0    297296.0    325385.0    355087.0    372652.0
# 9          중랑구    210497.0    216263.0    249836.0    274273.0    304261.0
# 10         성북구    296324.0    281229.0    302951.0    347725.0    370611.0
# 11         강북구    178484.0    167182.0    183257.0    208205.0    215529.0
# ...

# %%
TAX.to_csv('./data/TAX(2012-2020).csv')
